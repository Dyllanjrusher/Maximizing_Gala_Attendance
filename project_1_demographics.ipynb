# %% [markdown]
# ```
# Topic:        Project 1
# Subject:      Explore MTA turnstile data
# Date:         07/06/2020
# Names:        David Weon, Adam Rauckhorst, Dyllan Usher
#
# Notebook has been cleaned using nbextension 'Code prettify'
# ```

# %% [markdown]
# # Utilizing US Census Data for NY

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
sns.set(style='white', palette='colorblind')

# %%
demos = pd.read_csv('quickfacts.csv', index_col="Fact")
demos.head(50)
# Out:
#                                                    Fact Note  \
# Fact
# Population estimates, July 1, 2019,  (V2019)             NaN
# Population estimates base, April 1, 2010,  (V2019)       NaN
# Population, percent change - April 1, 2010 (est...       NaN
# Population, Census, April 1, 2010                        NaN
# Persons under 5 years, percent                           NaN
# Persons under 18 years, percent                          NaN
# Persons 65 years and over, percent                       NaN
# Female persons, percent                                  NaN
# White alone, percent                                     NaN
# Black or African American alone, percent                 (a)
# American Indian and Alaska Native alone, percent         (a)
# Asian alone, percent                                     (a)
# Native Hawaiian and Other Pacific Islander alon...       (a)
# Two or More Races, percent                               NaN
# Hispanic or Latino, percent                              (b)
# White alone, not Hispanic or Latino, percent             NaN
# Veterans, 2014-2018                                      NaN
# Foreign born persons, percent, 2014-2018                 NaN
# Housing units,  July 1, 2019,  (V2019)                   NaN
# Owner-occupied housing unit rate, 2014-2018              NaN
# Median value of owner-occupied housing units, 2...       NaN
# Median selected monthly owner costs -with a mor...       NaN
# Median selected monthly owner costs -without a ...       NaN
# Median gross rent, 2014-2018                             NaN
# Building permits, 2019                                   NaN
# Households, 2014-2018                                    NaN
# Persons per household, 2014-2018                         NaN
# Living in same house 1 year ago, percent of per...       NaN
# Language other than English spoken at home, per...       NaN
# Households with a computer, percent, 2014-2018           NaN
# Households with a broadband Internet subscripti...       NaN
# High school graduate or higher, percent of pers...       NaN
# Bachelor's degree or higher, percent of persons...       NaN
# With a disability, under age 65 years, percent,...       NaN
# Persons  without health insurance, under age 65...       NaN
# In civilian labor force, total, percent of popu...       NaN
# In civilian labor force, female, percent of pop...       NaN
# Total accommodation and food services sales, 20...       (c)
# Total health care and social assistance receipt...       (c)
# Total manufacturers shipments, 2012 ($1,000)             (c)
# Total merchant wholesaler sales, 2012 ($1,000)           (c)
# Total retail sales, 2012 ($1,000)                        (c)
# Total retail sales per capita, 2012                      (c)
# Mean travel time to work (minutes), workers age...       NaN
# Median household income (in 2018 dollars), 2014...       NaN
# Per capita income in past 12 months (in 2018 do...       NaN
# Persons in poverty, percent                              NaN
# Total employer establishments, 2018                      NaN
# Total employment, 2018                                   NaN
# Total annual payroll, 2018 ($1,000)                      NaN
#
#                                                    Kings County (Brooklyn Borough), New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                                       2,559,903
# Population estimates base, April 1, 2010,  (V2019)                                 2,504,721
# Population, percent change - April 1, 2010 (est...                                      2.2%
# Population, Census, April 1, 2010                                                  2,504,700
# Persons under 5 years, percent                                                          7.1%
# Persons under 18 years, percent                                                        22.7%
# Persons 65 years and over, percent                                                     14.4%
# Female persons, percent                                                                52.6%
# White alone, percent                                                                   49.8%
# Black or African American alone, percent                                               33.8%
# American Indian and Alaska Native alone, percent                                        0.9%
# Asian alone, percent                                                                   12.7%
# Native Hawaiian and Other Pacific Islander alon...                                      0.1%
# Two or More Races, percent                                                              2.7%
# Hispanic or Latino, percent                                                            18.9%
# White alone, not Hispanic or Latino, percent                                           36.8%
# Veterans, 2014-2018                                                                   38,322
# Foreign born persons, percent, 2014-2018                                               36.5%
# Housing units,  July 1, 2019,  (V2019)                                             1,065,399
# Owner-occupied housing unit rate, 2014-2018                                            30.0%
# Median value of owner-occupied housing units, 2...                                  $665,300
# Median selected monthly owner costs -with a mor...                                    $2,824
# Median selected monthly owner costs -without a ...                                      $878
# Median gross rent, 2014-2018                                                          $1,374
# Building permits, 2019                                                                 9,696
# Households, 2014-2018                                                                950,856
# Persons per household, 2014-2018                                                        2.69
# Living in same house 1 year ago, percent of per...                                     90.6%
# Language other than English spoken at home, per...                                     45.4%
# Households with a computer, percent, 2014-2018                                         85.8%
# Households with a broadband Internet subscripti...                                     77.6%
# High school graduate or higher, percent of pers...                                     81.6%
# Bachelor's degree or higher, percent of persons...                                     36.5%
# With a disability, under age 65 years, percent,...                                      6.1%
# Persons  without health insurance, under age 65...                                      7.8%
# In civilian labor force, total, percent of popu...                                     63.5%
# In civilian labor force, female, percent of pop...                                     59.2%
# Total accommodation and food services sales, 20...                                 2,453,405
# Total health care and social assistance receipt...                                16,419,598
# Total manufacturers shipments, 2012 ($1,000)                                       3,644,086
# Total merchant wholesaler sales, 2012 ($1,000)                                    16,522,942
# Total retail sales, 2012 ($1,000)                                                 20,533,079
# Total retail sales per capita, 2012                                                   $8,003
# Mean travel time to work (minutes), workers age...                                      42.6
# Median household income (in 2018 dollars), 2014...                                   $56,015
# Per capita income in past 12 months (in 2018 do...                                   $31,984
# Persons in poverty, percent                                                            18.9%
# Total employer establishments, 2018                                                   59,792
# Total employment, 2018                                                               655,714
# Total annual payroll, 2018 ($1,000)                                               27,660,905
#
#                                                     Value Note for Kings County (Brooklyn Borough), New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                                                      NaN
# Population estimates base, April 1, 2010,  (V2019)                                                NaN
# Population, percent change - April 1, 2010 (est...                                                NaN
# Population, Census, April 1, 2010                                                                 NaN
# Persons under 5 years, percent                                                                    NaN
# Persons under 18 years, percent                                                                   NaN
# Persons 65 years and over, percent                                                                NaN
# Female persons, percent                                                                           NaN
# White alone, percent                                                                              NaN
# Black or African American alone, percent                                                          NaN
# American Indian and Alaska Native alone, percent                                                  NaN
# Asian alone, percent                                                                              NaN
# Native Hawaiian and Other Pacific Islander alon...                                                NaN
# Two or More Races, percent                                                                        NaN
# Hispanic or Latino, percent                                                                       NaN
# White alone, not Hispanic or Latino, percent                                                      NaN
# Veterans, 2014-2018                                                                               NaN
# Foreign born persons, percent, 2014-2018                                                          NaN
# Housing units,  July 1, 2019,  (V2019)                                                            NaN
# Owner-occupied housing unit rate, 2014-2018                                                       NaN
# Median value of owner-occupied housing units, 2...                                                NaN
# Median selected monthly owner costs -with a mor...                                                NaN
# Median selected monthly owner costs -without a ...                                                NaN
# Median gross rent, 2014-2018                                                                      NaN
# Building permits, 2019                                                                            NaN
# Households, 2014-2018                                                                             NaN
# Persons per household, 2014-2018                                                                  NaN
# Living in same house 1 year ago, percent of per...                                                NaN
# Language other than English spoken at home, per...                                                NaN
# Households with a computer, percent, 2014-2018                                                    NaN
# Households with a broadband Internet subscripti...                                                NaN
# High school graduate or higher, percent of pers...                                                NaN
# Bachelor's degree or higher, percent of persons...                                                NaN
# With a disability, under age 65 years, percent,...                                                NaN
# Persons  without health insurance, under age 65...                                                NaN
# In civilian labor force, total, percent of popu...                                                NaN
# In civilian labor force, female, percent of pop...                                                NaN
# Total accommodation and food services sales, 20...                                                NaN
# Total health care and social assistance receipt...                                                NaN
# Total manufacturers shipments, 2012 ($1,000)                                                      NaN
# Total merchant wholesaler sales, 2012 ($1,000)                                                    NaN
# Total retail sales, 2012 ($1,000)                                                                 NaN
# Total retail sales per capita, 2012                                                               NaN
# Mean travel time to work (minutes), workers age...                                                NaN
# Median household income (in 2018 dollars), 2014...                                                NaN
# Per capita income in past 12 months (in 2018 do...                                                NaN
# Persons in poverty, percent                                                                       NaN
# Total employer establishments, 2018                                                               NaN
# Total employment, 2018                                                                            NaN
# Total annual payroll, 2018 ($1,000)                                                               NaN
#
#                                                    Queens County (Queens Borough), New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                                      2,253,858
# Population estimates base, April 1, 2010,  (V2019)                                2,230,619
# Population, percent change - April 1, 2010 (est...                                     1.0%
# Population, Census, April 1, 2010                                                 2,230,722
# Persons under 5 years, percent                                                         6.1%
# Persons under 18 years, percent                                                       20.0%
# Persons 65 years and over, percent                                                    16.3%
# Female persons, percent                                                               51.5%
# White alone, percent                                                                  47.8%
# Black or African American alone, percent                                              20.7%
# American Indian and Alaska Native alone, percent                                       1.3%
# Asian alone, percent                                                                  26.9%
# Native Hawaiian and Other Pacific Islander alon...                                     0.2%
# Two or More Races, percent                                                             3.0%
# Hispanic or Latino, percent                                                           28.2%
# White alone, not Hispanic or Latino, percent                                          24.9%
# Veterans, 2014-2018                                                                  43,330
# Foreign born persons, percent, 2014-2018                                              47.3%
# Housing units,  July 1, 2019,  (V2019)                                              869,400
# Owner-occupied housing unit rate, 2014-2018                                           44.6%
# Median value of owner-occupied housing units, 2...                                 $504,900
# Median selected monthly owner costs -with a mor...                                   $2,549
# Median selected monthly owner costs -without a ...                                     $856
# Median gross rent, 2014-2018                                                         $1,520
# Building permits, 2019                                                                5,137
# Households, 2014-2018                                                               779,234
# Persons per household, 2014-2018                                                       2.91
# Living in same house 1 year ago, percent of per...                                    91.6%
# Language other than English spoken at home, per...                                    55.8%
# Households with a computer, percent, 2014-2018                                        88.8%
# Households with a broadband Internet subscripti...                                    81.9%
# High school graduate or higher, percent of pers...                                    81.5%
# Bachelor's degree or higher, percent of persons...                                    31.5%
# With a disability, under age 65 years, percent,...                                     5.6%
# Persons  without health insurance, under age 65...                                    10.1%
# In civilian labor force, total, percent of popu...                                    64.1%
# In civilian labor force, female, percent of pop...                                    57.6%
# Total accommodation and food services sales, 20...                                3,139,120
# Total health care and social assistance receipt...                               12,103,525
# Total manufacturers shipments, 2012 ($1,000)                                      4,438,082
# Total merchant wholesaler sales, 2012 ($1,000)                                   16,059,427
# Total retail sales, 2012 ($1,000)                                                17,003,207
# Total retail sales per capita, 2012                                                  $7,481
# Mean travel time to work (minutes), workers age...                                     44.1
# Median household income (in 2018 dollars), 2014...                                  $64,987
# Per capita income in past 12 months (in 2018 do...                                  $30,289
# Persons in poverty, percent                                                           11.6%
# Total employer establishments, 2018                                                  50,770
# Total employment, 2018                                                              585,188
# Total annual payroll, 2018 ($1,000)                                              29,642,182
#
#                                                     Value Note for Queens County (Queens Borough), New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                                                      NaN
# Population estimates base, April 1, 2010,  (V2019)                                                NaN
# Population, percent change - April 1, 2010 (est...                                                NaN
# Population, Census, April 1, 2010                                                                 NaN
# Persons under 5 years, percent                                                                    NaN
# Persons under 18 years, percent                                                                   NaN
# Persons 65 years and over, percent                                                                NaN
# Female persons, percent                                                                           NaN
# White alone, percent                                                                              NaN
# Black or African American alone, percent                                                          NaN
# American Indian and Alaska Native alone, percent                                                  NaN
# Asian alone, percent                                                                              NaN
# Native Hawaiian and Other Pacific Islander alon...                                                NaN
# Two or More Races, percent                                                                        NaN
# Hispanic or Latino, percent                                                                       NaN
# White alone, not Hispanic or Latino, percent                                                      NaN
# Veterans, 2014-2018                                                                               NaN
# Foreign born persons, percent, 2014-2018                                                          NaN
# Housing units,  July 1, 2019,  (V2019)                                                            NaN
# Owner-occupied housing unit rate, 2014-2018                                                       NaN
# Median value of owner-occupied housing units, 2...                                                NaN
# Median selected monthly owner costs -with a mor...                                                NaN
# Median selected monthly owner costs -without a ...                                                NaN
# Median gross rent, 2014-2018                                                                      NaN
# Building permits, 2019                                                                            NaN
# Households, 2014-2018                                                                             NaN
# Persons per household, 2014-2018                                                                  NaN
# Living in same house 1 year ago, percent of per...                                                NaN
# Language other than English spoken at home, per...                                                NaN
# Households with a computer, percent, 2014-2018                                                    NaN
# Households with a broadband Internet subscripti...                                                NaN
# High school graduate or higher, percent of pers...                                                NaN
# Bachelor's degree or higher, percent of persons...                                                NaN
# With a disability, under age 65 years, percent,...                                                NaN
# Persons  without health insurance, under age 65...                                                NaN
# In civilian labor force, total, percent of popu...                                                NaN
# In civilian labor force, female, percent of pop...                                                NaN
# Total accommodation and food services sales, 20...                                                NaN
# Total health care and social assistance receipt...                                                NaN
# Total manufacturers shipments, 2012 ($1,000)                                                      NaN
# Total merchant wholesaler sales, 2012 ($1,000)                                                    NaN
# Total retail sales, 2012 ($1,000)                                                                 NaN
# Total retail sales per capita, 2012                                                               NaN
# Mean travel time to work (minutes), workers age...                                                NaN
# Median household income (in 2018 dollars), 2014...                                                NaN
# Per capita income in past 12 months (in 2018 do...                                                NaN
# Persons in poverty, percent                                                                       NaN
# Total employer establishments, 2018                                                               NaN
# Total employment, 2018                                                                            NaN
# Total annual payroll, 2018 ($1,000)                                                               NaN
#
#                                                    Richmond County (Staten Island Borough), New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                                                 476,143
# Population estimates base, April 1, 2010,  (V2019)                                           468,730
# Population, percent change - April 1, 2010 (est...                                              1.6%
# Population, Census, April 1, 2010                                                            468,730
# Persons under 5 years, percent                                                                  5.7%
# Persons under 18 years, percent                                                                21.8%
# Persons 65 years and over, percent                                                             16.7%
# Female persons, percent                                                                        51.4%
# White alone, percent                                                                           74.5%
# Black or African American alone, percent                                                       11.6%
# American Indian and Alaska Native alone, percent                                                0.7%
# Asian alone, percent                                                                           10.9%
# Native Hawaiian and Other Pacific Islander alon...                                              0.1%
# Two or More Races, percent                                                                      2.2%
# Hispanic or Latino, percent                                                                    18.6%
# White alone, not Hispanic or Latino, percent                                                   59.6%
# Veterans, 2014-2018                                                                           16,157
# Foreign born persons, percent, 2014-2018                                                       23.0%
# Housing units,  July 1, 2019,  (V2019)                                                       181,751
# Owner-occupied housing unit rate, 2014-2018                                                    69.7%
# Median value of owner-occupied housing units, 2...                                          $478,600
# Median selected monthly owner costs -with a mor...                                            $2,493
# Median selected monthly owner costs -without a ...                                              $879
# Median gross rent, 2014-2018                                                                  $1,282
# Building permits, 2019                                                                           661
# Households, 2014-2018                                                                        166,152
# Persons per household, 2014-2018                                                                2.81
# Living in same house 1 year ago, percent of per...                                             94.1%
# Language other than English spoken at home, per...                                             31.9%
# Households with a computer, percent, 2014-2018                                                 88.3%
# Households with a broadband Internet subscripti...                                             81.1%
# High school graduate or higher, percent of pers...                                             88.5%
# Bachelor's degree or higher, percent of persons...                                             33.0%
# With a disability, under age 65 years, percent,...                                              6.4%
# Persons  without health insurance, under age 65...                                              5.3%
# In civilian labor force, total, percent of popu...                                             58.1%
# In civilian labor force, female, percent of pop...                                             52.8%
# Total accommodation and food services sales, 20...                                           472,571
# Total health care and social assistance receipt...                                         2,960,700
# Total manufacturers shipments, 2012 ($1,000)                                                 285,325
# Total merchant wholesaler sales, 2012 ($1,000)                                             1,460,048
# Total retail sales, 2012 ($1,000)                                                          3,815,951
# Total retail sales per capita, 2012                                                           $8,106
# Mean travel time to work (minutes), workers age...                                              44.5
# Median household income (in 2018 dollars), 2014...                                           $79,267
# Per capita income in past 12 months (in 2018 do...                                           $34,987
# Persons in poverty, percent                                                                    11.7%
# Total employer establishments, 2018                                                            9,435
# Total employment, 2018                                                                       105,648
# Total annual payroll, 2018 ($1,000)                                                        4,573,941
#
#                                                     Value Note for Richmond County (Staten Island Borough), New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                                                      NaN
# Population estimates base, April 1, 2010,  (V2019)                                                NaN
# Population, percent change - April 1, 2010 (est...                                                NaN
# Population, Census, April 1, 2010                                                                 NaN
# Persons under 5 years, percent                                                                    NaN
# Persons under 18 years, percent                                                                   NaN
# Persons 65 years and over, percent                                                                NaN
# Female persons, percent                                                                           NaN
# White alone, percent                                                                              NaN
# Black or African American alone, percent                                                          NaN
# American Indian and Alaska Native alone, percent                                                  NaN
# Asian alone, percent                                                                              NaN
# Native Hawaiian and Other Pacific Islander alon...                                                NaN
# Two or More Races, percent                                                                        NaN
# Hispanic or Latino, percent                                                                       NaN
# White alone, not Hispanic or Latino, percent                                                      NaN
# Veterans, 2014-2018                                                                               NaN
# Foreign born persons, percent, 2014-2018                                                          NaN
# Housing units,  July 1, 2019,  (V2019)                                                            NaN
# Owner-occupied housing unit rate, 2014-2018                                                       NaN
# Median value of owner-occupied housing units, 2...                                                NaN
# Median selected monthly owner costs -with a mor...                                                NaN
# Median selected monthly owner costs -without a ...                                                NaN
# Median gross rent, 2014-2018                                                                      NaN
# Building permits, 2019                                                                            NaN
# Households, 2014-2018                                                                             NaN
# Persons per household, 2014-2018                                                                  NaN
# Living in same house 1 year ago, percent of per...                                                NaN
# Language other than English spoken at home, per...                                                NaN
# Households with a computer, percent, 2014-2018                                                    NaN
# Households with a broadband Internet subscripti...                                                NaN
# High school graduate or higher, percent of pers...                                                NaN
# Bachelor's degree or higher, percent of persons...                                                NaN
# With a disability, under age 65 years, percent,...                                                NaN
# Persons  without health insurance, under age 65...                                                NaN
# In civilian labor force, total, percent of popu...                                                NaN
# In civilian labor force, female, percent of pop...                                                NaN
# Total accommodation and food services sales, 20...                                                NaN
# Total health care and social assistance receipt...                                                NaN
# Total manufacturers shipments, 2012 ($1,000)                                                      NaN
# Total merchant wholesaler sales, 2012 ($1,000)                                                    NaN
# Total retail sales, 2012 ($1,000)                                                                 NaN
# Total retail sales per capita, 2012                                                               NaN
# Mean travel time to work (minutes), workers age...                                                NaN
# Median household income (in 2018 dollars), 2014...                                                NaN
# Per capita income in past 12 months (in 2018 do...                                                NaN
# Persons in poverty, percent                                                                       NaN
# Total employer establishments, 2018                                                               NaN
# Total employment, 2018                                                                            NaN
# Total annual payroll, 2018 ($1,000)                                                               NaN
#
#                                                    New York County (Manhattan Borough), New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                                           1,628,706
# Population estimates base, April 1, 2010,  (V2019)                                     1,586,381
# Population, percent change - April 1, 2010 (est...                                          2.7%
# Population, Census, April 1, 2010                                                      1,585,873
# Persons under 5 years, percent                                                              4.7%
# Persons under 18 years, percent                                                            14.3%
# Persons 65 years and over, percent                                                         17.0%
# Female persons, percent                                                                    52.6%
# White alone, percent                                                                       64.6%
# Black or African American alone, percent                                                   17.8%
# American Indian and Alaska Native alone, percent                                            1.2%
# Asian alone, percent                                                                       12.8%
# Native Hawaiian and Other Pacific Islander alon...                                          0.2%
# Two or More Races, percent                                                                  3.4%
# Hispanic or Latino, percent                                                                25.6%
# White alone, not Hispanic or Latino, percent                                               47.2%
# Veterans, 2014-2018                                                                       32,519
# Foreign born persons, percent, 2014-2018                                                   29.0%
# Housing units,  July 1, 2019,  (V2019)                                                   892,878
# Owner-occupied housing unit rate, 2014-2018                                                24.1%
# Median value of owner-occupied housing units, 2...                                      $944,600
# Median selected monthly owner costs -with a mor...                                        $3,186
# Median selected monthly owner costs -without a ...                                        $1,014
# Median gross rent, 2014-2018                                                              $1,682
# Building permits, 2019                                                                     5,512
# Households, 2014-2018                                                                    758,133
# Persons per household, 2014-2018                                                            2.07
# Living in same house 1 year ago, percent of per...                                         84.7%
# Language other than English spoken at home, per...                                         39.7%
# Households with a computer, percent, 2014-2018                                             90.1%
# Households with a broadband Internet subscripti...                                         83.3%
# High school graduate or higher, percent of pers...                                         87.0%
# Bachelor's degree or higher, percent of persons...                                         60.8%
# With a disability, under age 65 years, percent,...                                          6.1%
# Persons  without health insurance, under age 65...                                          6.1%
# In civilian labor force, total, percent of popu...                                         67.0%
# In civilian labor force, female, percent of pop...                                         62.5%
# Total accommodation and food services sales, 20...                                    20,382,622
# Total health care and social assistance receipt...                                    34,680,452
# Total manufacturers shipments, 2012 ($1,000)                                           4,970,920
# Total merchant wholesaler sales, 2012 ($1,000)                                       128,760,891
# Total retail sales, 2012 ($1,000)                                                     44,039,957
# Total retail sales per capita, 2012                                                      $27,200
# Mean travel time to work (minutes), workers age...                                          32.1
# Median household income (in 2018 dollars), 2014...                                       $82,459
# Per capita income in past 12 months (in 2018 do...                                       $72,832
# Persons in poverty, percent                                                                15.6%
# Total employer establishments, 2018                                                      102,903
# Total employment, 2018                                                                 2,276,786
# Total annual payroll, 2018 ($1,000)                                                  263,303,530
#
#                                                     Value Note for New York County (Manhattan Borough), New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                                                      NaN
# Population estimates base, April 1, 2010,  (V2019)                                                NaN
# Population, percent change - April 1, 2010 (est...                                                NaN
# Population, Census, April 1, 2010                                                                 NaN
# Persons under 5 years, percent                                                                    NaN
# Persons under 18 years, percent                                                                   NaN
# Persons 65 years and over, percent                                                                NaN
# Female persons, percent                                                                           NaN
# White alone, percent                                                                              NaN
# Black or African American alone, percent                                                          NaN
# American Indian and Alaska Native alone, percent                                                  NaN
# Asian alone, percent                                                                              NaN
# Native Hawaiian and Other Pacific Islander alon...                                                NaN
# Two or More Races, percent                                                                        NaN
# Hispanic or Latino, percent                                                                       NaN
# White alone, not Hispanic or Latino, percent                                                      NaN
# Veterans, 2014-2018                                                                               NaN
# Foreign born persons, percent, 2014-2018                                                          NaN
# Housing units,  July 1, 2019,  (V2019)                                                            NaN
# Owner-occupied housing unit rate, 2014-2018                                                       NaN
# Median value of owner-occupied housing units, 2...                                                NaN
# Median selected monthly owner costs -with a mor...                                                NaN
# Median selected monthly owner costs -without a ...                                                NaN
# Median gross rent, 2014-2018                                                                      NaN
# Building permits, 2019                                                                            NaN
# Households, 2014-2018                                                                             NaN
# Persons per household, 2014-2018                                                                  NaN
# Living in same house 1 year ago, percent of per...                                                NaN
# Language other than English spoken at home, per...                                                NaN
# Households with a computer, percent, 2014-2018                                                    NaN
# Households with a broadband Internet subscripti...                                                NaN
# High school graduate or higher, percent of pers...                                                NaN
# Bachelor's degree or higher, percent of persons...                                                NaN
# With a disability, under age 65 years, percent,...                                                NaN
# Persons  without health insurance, under age 65...                                                NaN
# In civilian labor force, total, percent of popu...                                                NaN
# In civilian labor force, female, percent of pop...                                                NaN
# Total accommodation and food services sales, 20...                                                NaN
# Total health care and social assistance receipt...                                                NaN
# Total manufacturers shipments, 2012 ($1,000)                                                      NaN
# Total merchant wholesaler sales, 2012 ($1,000)                                                    NaN
# Total retail sales, 2012 ($1,000)                                                                 NaN
# Total retail sales per capita, 2012                                                               NaN
# Mean travel time to work (minutes), workers age...                                                NaN
# Median household income (in 2018 dollars), 2014...                                                NaN
# Per capita income in past 12 months (in 2018 do...                                                NaN
# Persons in poverty, percent                                                                       NaN
# Total employer establishments, 2018                                                               NaN
# Total employment, 2018                                                                            NaN
# Total annual payroll, 2018 ($1,000)                                                               NaN
#
#                                                    Bronx County (Bronx Borough), New York  \
# Fact
# ...
# In civilian labor force, total, percent of popu...                                  59.7%
# In civilian labor force, female, percent of pop...                                  55.6%
# Total accommodation and food services sales, 20...                              1,005,143
# Total health care and social assistance receipt...                             10,001,272
# Total manufacturers shipments, 2012 ($1,000)                                    1,477,909
# Total merchant wholesaler sales, 2012 ($1,000)                                 10,994,538
# Total retail sales, 2012 ($1,000)                                               6,872,806
# Total retail sales per capita, 2012                                                $4,880
# Mean travel time to work (minutes), workers age...                                   44.8
# Median household income (in 2018 dollars), 2014...                                $38,085
# Per capita income in past 12 months (in 2018 do...                                $20,850
# Persons in poverty, percent                                                         27.3%
# Total employer establishments, 2018                                                18,309
# Total employment, 2018                                                            271,541
# Total annual payroll, 2018 ($1,000)                                            12,886,127
#
#                                                     Value Note for Bronx County (Bronx Borough), New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                                                      NaN
# Population estimates base, April 1, 2010,  (V2019)                                                NaN
# Population, percent change - April 1, 2010 (est...                                                NaN
# Population, Census, April 1, 2010                                                                 NaN
# Persons under 5 years, percent                                                                    NaN
# Persons under 18 years, percent                                                                   NaN
# Persons 65 years and over, percent                                                                NaN
# Female persons, percent                                                                           NaN
# White alone, percent                                                                              NaN
# Black or African American alone, percent                                                          NaN
# American Indian and Alaska Native alone, percent                                                  NaN
# Asian alone, percent                                                                              NaN
# Native Hawaiian and Other Pacific Islander alon...                                                NaN
# Two or More Races, percent                                                                        NaN
# Hispanic or Latino, percent                                                                       NaN
# White alone, not Hispanic or Latino, percent                                                      NaN
# Veterans, 2014-2018                                                                               NaN
# Foreign born persons, percent, 2014-2018                                                          NaN
# Housing units,  July 1, 2019,  (V2019)                                                            NaN
# Owner-occupied housing unit rate, 2014-2018                                                       NaN
# Median value of owner-occupied housing units, 2...                                                NaN
# Median selected monthly owner costs -with a mor...                                                NaN
# Median selected monthly owner costs -without a ...                                                NaN
# Median gross rent, 2014-2018                                                                      NaN
# Building permits, 2019                                                                            NaN
# Households, 2014-2018                                                                             NaN
# Persons per household, 2014-2018                                                                  NaN
# Living in same house 1 year ago, percent of per...                                                NaN
# Language other than English spoken at home, per...                                                NaN
# Households with a computer, percent, 2014-2018                                                    NaN
# Households with a broadband Internet subscripti...                                                NaN
# High school graduate or higher, percent of pers...                                                NaN
# Bachelor's degree or higher, percent of persons...                                                NaN
# With a disability, under age 65 years, percent,...                                                NaN
# Persons  without health insurance, under age 65...                                                NaN
# In civilian labor force, total, percent of popu...                                                NaN
# In civilian labor force, female, percent of pop...                                                NaN
# Total accommodation and food services sales, 20...                                                NaN
# Total health care and social assistance receipt...                                                NaN
# Total manufacturers shipments, 2012 ($1,000)                                                      NaN
# Total merchant wholesaler sales, 2012 ($1,000)                                                    NaN
# Total retail sales, 2012 ($1,000)                                                                 NaN
# Total retail sales per capita, 2012                                                               NaN
# Mean travel time to work (minutes), workers age...                                                NaN
# Median household income (in 2018 dollars), 2014...                                                NaN
# Per capita income in past 12 months (in 2018 do...                                                NaN
# Persons in poverty, percent                                                                       NaN
# Total employer establishments, 2018                                                               NaN
# Total employment, 2018                                                                            NaN
# Total annual payroll, 2018 ($1,000)                                                               NaN
#
#                                                    New York city, New York  \
# Fact
# Population estimates, July 1, 2019,  (V2019)                     8,336,817
# Population estimates base, April 1, 2010,  (V2019)               8,175,031
# Population, percent change - April 1, 2010 (est...                    2.0%
# Population, Census, April 1, 2010                                8,175,133
# Persons under 5 years, percent                                        6.5%
# Persons under 18 years, percent                                      20.9%
# Persons 65 years and over, percent                                   14.1%
# Female persons, percent                                              52.3%
# White alone, percent                                                 42.7%
# Black or African American alone, percent                             24.3%
# American Indian and Alaska Native alone, percent                      0.4%
# Asian alone, percent                                                 13.9%
# Native Hawaiian and Other Pacific Islander alon...                    0.1%
# Two or More Races, percent                                            3.5%
# Hispanic or Latino, percent                                          29.1%
# White alone, not Hispanic or Latino, percent                         32.1%
# Veterans, 2014-2018                                                156,514
# Foreign born persons, percent, 2014-2018                             37.0%
# Housing units,  July 1, 2019,  (V2019)                                   X
# Owner-occupied housing unit rate, 2014-2018                          32.7%
# Median value of owner-occupied housing units, 2...                $570,500
# Median selected monthly owner costs -with a mor...                  $2,665
# Median selected monthly owner costs -without a ...                    $871
# Median gross rent, 2014-2018                                        $1,396
# Building permits, 2019                                                   X
# Households, 2014-2018                                            3,154,103
# Persons per household, 2014-2018                                      2.62
# Living in same house 1 year ago, percent of per...                   90.0%
# Language other than English spoken at home, per...                   48.7%
# Households with a computer, percent, 2014-2018                       87.5%
# Households with a broadband Internet subscripti...                   79.4%
# High school graduate or higher, percent of pers...                   81.6%
# Bachelor's degree or higher, percent of persons...                   37.4%
# With a disability, under age 65 years, percent,...                    6.8%
# Persons  without health insurance, under age 65...                    9.6%
# In civilian labor force, total, percent of popu...                   63.5%
# In civilian labor force, female, percent of pop...                   58.5%
# Total accommodation and food services sales, 20...              27,452,861
# Total health care and social assistance receipt...              76,165,547
# Total manufacturers shipments, 2012 ($1,000)                    14,816,322
# Total merchant wholesaler sales, 2012 ($1,000)                 173,797,846
# Total retail sales, 2012 ($1,000)                               92,265,000
# Total retail sales per capita, 2012                                $11,067
# Mean travel time to work (minutes), workers age...                    41.2
# Median household income (in 2018 dollars), 2014...                 $60,762
# Per capita income in past 12 months (in 2018 do...                 $37,693
# Persons in poverty, percent                                          18.9%
# Total employer establishments, 2018                                      X
# Total employment, 2018                                                   X
# Total annual payroll, 2018 ($1,000)                                      X
#
#                                                     Value Note for New York city, New York
# Fact
# Population estimates, July 1, 2019,  (V2019)                                           NaN
# Population estimates base, April 1, 2010,  (V2019)                                     NaN
# Population, percent change - April 1, 2010 (est...                                     NaN
# Population, Census, April 1, 2010                                                      NaN
# Persons under 5 years, percent                                                         NaN
# Persons under 18 years, percent                                                        NaN
# Persons 65 years and over, percent                                                     NaN
# Female persons, percent                                                                NaN
# White alone, percent                                                                   NaN
# Black or African American alone, percent                                               NaN
# American Indian and Alaska Native alone, percent                                       NaN
# Asian alone, percent                                                                   NaN
# Native Hawaiian and Other Pacific Islander alon...                                     NaN
# Two or More Races, percent                                                             NaN
# Hispanic or Latino, percent                                                            NaN
# White alone, not Hispanic or Latino, percent                                           NaN
# Veterans, 2014-2018                                                                    NaN
# Foreign born persons, percent, 2014-2018                                               NaN
# Housing units,  July 1, 2019,  (V2019)                                                 NaN
# Owner-occupied housing unit rate, 2014-2018                                            NaN
# Median value of owner-occupied housing units, 2...                                     NaN
# Median selected monthly owner costs -with a mor...                                     NaN
# Median selected monthly owner costs -without a ...                                     NaN
# Median gross rent, 2014-2018                                                           NaN
# Building permits, 2019                                                                 NaN
# Households, 2014-2018                                                                  NaN
# Persons per household, 2014-2018                                                       NaN
# Living in same house 1 year ago, percent of per...                                     NaN
# Language other than English spoken at home, per...                                     NaN
# Households with a computer, percent, 2014-2018                                         NaN
# Households with a broadband Internet subscripti...                                     NaN
# High school graduate or higher, percent of pers...                                     NaN
# Bachelor's degree or higher, percent of persons...                                     NaN
# With a disability, under age 65 years, percent,...                                     NaN
# Persons  without health insurance, under age 65...                                     NaN
# In civilian labor force, total, percent of popu...                                     NaN
# In civilian labor force, female, percent of pop...                                     NaN
# Total accommodation and food services sales, 20...                                     NaN
# Total health care and social assistance receipt...                                     NaN
# Total manufacturers shipments, 2012 ($1,000)                                           NaN
# Total merchant wholesaler sales, 2012 ($1,000)                                         NaN
# Total retail sales, 2012 ($1,000)                                                      NaN
# Total retail sales per capita, 2012                                                    NaN
# Mean travel time to work (minutes), workers age...                                     NaN
# Median household income (in 2018 dollars), 2014...                                     NaN
# Per capita income in past 12 months (in 2018 do...                                     NaN
# Persons in poverty, percent                                                            NaN
# Total employer establishments, 2018                                                    NaN
# Total employment, 2018                                                                 NaN
# Total annual payroll, 2018 ($1,000)                                                    NaN

# %%
#get rid of ugly columns
demos = demos.drop(columns=[column for column in demos.columns[::2]])

# %%
#renamed columns
demos.columns = ['Brooklyn', 'Queens', 'Staten Island', 'Manhattan', 'Bronx', 'NYC_Total']
demos.columns
# Out:
# Index(['Brooklyn', 'Queens', 'Staten Island', 'Manhattan', 'Bronx',
#        'NYC_Total'],
#       dtype='object')

# %%
demos.drop('NYC_Total', axis=1, inplace=True)

# %% [markdown]
# ## Median Income

# %%
#median income
income = demos.loc['Median household income (in 2018 dollars), 2014-2018']
income = income.str.replace('$', '')
income = income.str.replace(',', '')
income = income.astype(int)
income = income.reset_index()
income.columns = ['Bor', 'Median_Income']
income
# Out:
#              Bor  Median_Income
# 0       Brooklyn          56015
# 1         Queens          64987
# 2  Staten Island          79267
# 3      Manhattan          82459
# 4          Bronx          38085

# %%
#plotting median income by NYC borough
plt.figure(figsize=(10, 5))
sns.barplot(x='Bor', y='Median_Income', data=income)
plt.title("Median Income By NY Borough", size=20, weight='bold')
plt.ylabel('Median Household Income ($)', size=13)
plt.xlabel('NYC Borough', size=13)
sns.despine()
plt.savefig('Median_Income.png', dpi=600)

# %% [markdown]
# ## Number of Women-Owned Firms

# %%
#women owned firms
wof = demos.loc['Women-owned firms, 2012']
wof = wof.str.replace(',', '')
wof = wof.astype(int)
wof = wof.reset_index()
wof.columns = ['Bor', 'Women_Owned_Firms']

# %%
#plotting by number of women owned firms by NY borough
plt.figure(figsize=(10, 5))
sns.barplot(x='Bor', y='Women_Owned_Firms', data=wof)
plt.xlabel('NYC Borough', size=13)
plt.ylabel('Women Owned Firms', size=13)
plt.title("Women Owned Firms By NY Borough", size=20, weight='bold')
sns.despine()
plt.savefig('Women_Owned_Firms.png', dpi=600)

# %%
#put values on top of bars

# %% [markdown]
# ## Percentage of Women by Borough

# %%
#%women, a sanity check
pct_w = demos.loc["Female persons, percent"]
pct_w = pct_w.str.replace('%', '')
pct_w = pct_w.astype(float)
pct_w = pct_w.reset_index()
pct_w.columns = ['Bor', 'Percentage_Women']

# %%
#plotting percentage of women by borough
plt.figure(figsize=(10, 5))
sns.barplot(x='Bor', y='Percentage_Women', data=pct_w)
plt.xlabel('NYC Borough', size=13)
plt.ylabel('Women %', size=13)
plt.title("Percentage of Women By Borough", size=20, weight='bold')
sns.despine()
plt.savefig('Percentageofwomen.png', dpi=600)
